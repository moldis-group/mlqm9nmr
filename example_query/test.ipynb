# %% [markdown]
# #### a)

# %%
# Installation
# ! pip3 install cebeconf

# %%
from cebeconf import calc_be
import numpy as np

# %% [markdown]
# #### b)

# %%
calc_be('test.xyz', 'direct', 'ACM')
# Out:
#  Calculation started on 2024-08-15 14:18:51
#
#              _                                __
#             | |                              / _|
#    ___  ___ | |__    ___   ___  ___   _ __  | |_
#   / __|/ _ \| '_ \  / _ \ / __|/ _ \ | '_ \ |  _|
#  | (__|  __/| |_) ||  __/| (__| (_) || | | || |
#   \___|\___||_.__/  \___| \___|\___/ |_| |_||_|
#
#
#  This is an ML model for predicting 1s core binding
#  energies of CONF atoms. The model is trained on data
#  calculated using Delta-SCF approach with the mGGA-DFT
#  method, SCAN, at the basis set limit.
#
#  The model assumes that the input geometry is relaxed using
#  universal force fields (UFF).
#
#  If Delta-ML prediction is requested, the ML estimates
#  the difference in SCAN Delta-SCF values from Koopmans
#  estimation based on PBE/cc-pVDZ on UFF geometry.
#
#  Some reference values determined with the SCAN Delta-SCF  method:
#
#  C in CH4, methane      290.94 eV
#  C in CH3CH3, ethane    290.78 eV
# ...

# %% [markdown]
# #### c)

# %%
calc_be('test.xyz', 'direct', 'AtmEnv')
# Out:
#  Calculation started on 2024-08-15 14:18:51
#
#              _                                __
#             | |                              / _|
#    ___  ___ | |__    ___   ___  ___   _ __  | |_
#   / __|/ _ \| '_ \  / _ \ / __|/ _ \ | '_ \ |  _|
#  | (__|  __/| |_) ||  __/| (__| (_) || | | || |
#   \___|\___||_.__/  \___| \___|\___/ |_| |_||_|
#
#
#  This is an ML model for predicting 1s core binding
#  energies of CONF atoms. The model is trained on data
#  calculated using Delta-SCF approach with the mGGA-DFT
#  method, SCAN, at the basis set limit.
#
#  The model assumes that the input geometry is relaxed using
#  universal force fields (UFF).
#
#  If Delta-ML prediction is requested, the ML estimates
#  the difference in SCAN Delta-SCF values from Koopmans
#  estimation based on PBE/cc-pVDZ on UFF geometry.
#
#  Some reference values determined with the SCAN Delta-SCF  method:
#
#  C in CH4, methane      290.94 eV
#  C in CH3CH3, ethane    290.78 eV
# ...

# %% [markdown]
# #### d)

# %%
calc_be('test.xyz', 'delta', 'ACM', [272.44, 510.77, 272.21, 662.82, 271.86, 383.90, 273.48, 510.94, 383.33])
# Out:
#  Calculation started on 2024-08-15 14:18:51
#
#              _                                __
#             | |                              / _|
#    ___  ___ | |__    ___   ___  ___   _ __  | |_
#   / __|/ _ \| '_ \  / _ \ / __|/ _ \ | '_ \ |  _|
#  | (__|  __/| |_) ||  __/| (__| (_) || | | || |
#   \___|\___||_.__/  \___| \___|\___/ |_| |_||_|
#
#
#  This is an ML model for predicting 1s core binding
#  energies of CONF atoms. The model is trained on data
#  calculated using Delta-SCF approach with the mGGA-DFT
#  method, SCAN, at the basis set limit.
#
#  The model assumes that the input geometry is relaxed using
#  universal force fields (UFF).
#
#  If Delta-ML prediction is requested, the ML estimates
#  the difference in SCAN Delta-SCF values from Koopmans
#  estimation based on PBE/cc-pVDZ on UFF geometry.
#
#  Some reference values determined with the SCAN Delta-SCF  method:
#
#  C in CH4, methane      290.94 eV
#  C in CH3CH3, ethane    290.78 eV
# ...

# %% [markdown]
# #### e)

# %%
calc_be('test.xyz', 'delta', 'AtmEnv', [272.44, 510.77, 272.21, 662.82, 271.86, 383.90, 273.48, 510.94, 383.33])
# Out:
#  Calculation started on 2024-08-15 14:18:51
#
#              _                                __
#             | |                              / _|
#    ___  ___ | |__    ___   ___  ___   _ __  | |_
#   / __|/ _ \| '_ \  / _ \ / __|/ _ \ | '_ \ |  _|
#  | (__|  __/| |_) ||  __/| (__| (_) || | | || |
#   \___|\___||_.__/  \___| \___|\___/ |_| |_||_|
#
#
#  This is an ML model for predicting 1s core binding
#  energies of CONF atoms. The model is trained on data
#  calculated using Delta-SCF approach with the mGGA-DFT
#  method, SCAN, at the basis set limit.
#
#  The model assumes that the input geometry is relaxed using
#  universal force fields (UFF).
#
#  If Delta-ML prediction is requested, the ML estimates
#  the difference in SCAN Delta-SCF values from Koopmans
#  estimation based on PBE/cc-pVDZ on UFF geometry.
#
#  Some reference values determined with the SCAN Delta-SCF  method:
#
#  C in CH4, methane      290.94 eV
#  C in CH3CH3, ethane    290.78 eV
# ...

# %% [markdown]
# #### f)

# %%
calc_be('test.xyz', 'delta', 'AtmEnv')
# Out:
#  Calculation started on 2024-08-15 14:18:51
#
#              _                                __
#             | |                              / _|
#    ___  ___ | |__    ___   ___  ___   _ __  | |_
#   / __|/ _ \| '_ \  / _ \ / __|/ _ \ | '_ \ |  _|
#  | (__|  __/| |_) ||  __/| (__| (_) || | | || |
#   \___|\___||_.__/  \___| \___|\___/ |_| |_||_|
#
#
#  This is an ML model for predicting 1s core binding
#  energies of CONF atoms. The model is trained on data
#  calculated using Delta-SCF approach with the mGGA-DFT
#  method, SCAN, at the basis set limit.
#
#  The model assumes that the input geometry is relaxed using
#  universal force fields (UFF).
#
#  If Delta-ML prediction is requested, the ML estimates
#  the difference in SCAN Delta-SCF values from Koopmans
#  estimation based on PBE/cc-pVDZ on UFF geometry.
#
#  Some reference values determined with the SCAN Delta-SCF  method:
#
#  C in CH4, methane      290.94 eV
#  C in CH3CH3, ethane    290.78 eV
# ...

# %% [markdown]
# #### g)

# %%
delta_predictions = np.array(calc_be('test.xyz', 'delta', 'AtmEnv'))
baseline_energies = np.array([272.44, 510.77, 272.21, 662.82, 271.86, 383.90, 273.48, 510.94, 383.33])
predicted_energies = delta_predictions + baseline_energies
# Out:
#  Calculation started on 2024-08-15 14:18:51
#
#              _                                __
#             | |                              / _|
#    ___  ___ | |__    ___   ___  ___   _ __  | |_
#   / __|/ _ \| '_ \  / _ \ / __|/ _ \ | '_ \ |  _|
#  | (__|  __/| |_) ||  __/| (__| (_) || | | || |
#   \___|\___||_.__/  \___| \___|\___/ |_| |_||_|
#
#
#  This is an ML model for predicting 1s core binding
#  energies of CONF atoms. The model is trained on data
#  calculated using Delta-SCF approach with the mGGA-DFT
#  method, SCAN, at the basis set limit.
#
#  The model assumes that the input geometry is relaxed using
#  universal force fields (UFF).
#
#  If Delta-ML prediction is requested, the ML estimates
#  the difference in SCAN Delta-SCF values from Koopmans
#  estimation based on PBE/cc-pVDZ on UFF geometry.
#
#  Some reference values determined with the SCAN Delta-SCF  method:
#
#  C in CH4, methane      290.94 eV
#  C in CH3CH3, ethane    290.78 eV
# ...

# %%
print(predicted_energies)
# Out:
# [294.329458   537.98754334 293.35750165 694.32973746 292.65963218
#  407.39278698 295.49650958 538.30288627 406.81765325]
