# %%
from mlqm9nmr import calc_nmr
from mlqm9nmr import plot_nmr

filename   = 'test.xyz'
descriptor = 'abob_rbf_4_uff'

cs = calc_nmr(filename,descriptor,di_path='bz2')
plot_nmr(cs)
# Out:
# C1      14.80 ppm (<p5)
# C2      34.42 ppm (<p5)
# C3      31.10 ppm (<p5)
# C4      36.76 ppm (<p5)
# C5       5.27 ppm (<p5)
# C6       6.48 ppm (<p5)
